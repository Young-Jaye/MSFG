# %% [markdown]
# # Tutorial: MSFG Quick Start
#
# Audience:
# - Researchers who want to reproduce an MSFG experiment from a recorded configuration.
#
# Prerequisites:
# - Install the packages in `requirements.txt`.
# - Prepare one dataset using the layout in `data/README.md`.
# - Launch Jupyter from the repository root or from this `notebooks/` directory.
#
# Learning goals:
# - Inspect a YAML configuration and launch the exact same training API as the CLI.

# %% [markdown]
# ## Outline
#
# 1. Setup
# 2. Inspect a reproducible configuration
# 3. Launch training
# 4. Exercise and pitfalls

# %%
from __future__ import annotations

import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))
PROJECT_ROOT

# %% [markdown]
# ## Step 1 — Inspect the experiment configuration
#
# Configuration is stored outside the source code. The loader flattens the documented YAML sections into the unchanged runner parameter dictionary.

# %%
from config import load_config

config_path = PROJECT_ROOT / 'configs' / 'paper' / 'dlpfc_151507.yaml'
config = load_config(config_path)
config

# %% [markdown]
# ## Step 2 — Launch training
#
# The next cell calls the same function used by `python train.py --config ...`. It is intentionally commented to prevent an accidental long GPU/CPU run. Remove the leading `#` after preparing the dataset.

# %%
from train import run_from_config

# best_ari = run_from_config(config_path)
# best_ari

# %% [markdown]
# ## Exercises
#
# - Copy `configs/paper/dlpfc_151507.yaml`, change only `dataset`, and inspect the loaded dictionary.
# - Do not paste model or loss code into this notebook; always import the production API.
# - Common pitfall: launching outside the repository root can break relative data paths.

# %%
example = dict(config)
example['dataset'] = '151508'
{key: example[key] for key in ('dataset', 'seed', 'epochs')}
